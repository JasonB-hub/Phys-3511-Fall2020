# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Scientific-Computing-at-Temple-Physics/Phys-3511-Fall2020/master/Module05/data/nobel.csv")
print(df)
# Out:
#      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 906  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 907  2016       Peace                      The Nobel Peace Prize 2016
# 908  2016     Physics                 The Nobel Prize in Physics 2016
# 909  2016     Physics                 The Nobel Prize in Physics 2016
# 910  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 911 entries, 0 to 910
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  911 non-null    int64
#  1   category              911 non-null    object
#  2   prize                 911 non-null    object
#  3   motivation            823 non-null    object
#  4   prize_share           911 non-null    object
#  5   laureate_id           911 non-null    int64
#  6   laureate_type         911 non-null    object
#  7   full_name             911 non-null    object
#  8   birth_date            883 non-null    object
#  9   birth_city            883 non-null    object
#  10  birth_country         885 non-null    object
#  11  sex                   885 non-null    object
#  12  organization_name     665 non-null    object
#  13  organization_city     667 non-null    object
#  14  organization_country  667 non-null    object
# ...

# %%
df.iloc[0:5,:]
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   laureate_type                     full_name  birth_date         birth_city  \
# ...

# %%
df.isnull().sum(axis = 0)
# Out:
# year                      0
# category                  0
# prize                     0
# motivation               88
# prize_share               0
# laureate_id               0
# laureate_type             0
# full_name                 0
# birth_date               28
# birth_city               28
# birth_country            26
# sex                      26
# organization_name       246
# organization_city       244
# organization_country    244
# death_date              318
# death_city              335
# death_country           329
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 1912

# %%
df.hist('year',bins = 10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc76dcf5c70>]],
#       dtype=object)

# %%
#The least amount of prizes were awarded in the 1910-1920 decade

# %%
count = df.groupby(['category']).size()
print(count)
# Out:
# category
# Chemistry     175
# Economics      78
# Literature    113
# Medicine      211
# Peace         130
# Physics       204
# dtype: int64

# %%
#Medicine has the most Nobel Prizes

# %%
count2 = df.groupby(['prize_share']).size()
print(count2)
# Out:
# prize_share
# 1/1    344
# 1/2    306
# 1/3    201
# 1/4     60
# dtype: int64

# %%
def percent(x):
    return (x/911)*100

# %%
count2.apply(percent)
# Out:
# prize_share
# 1/1    37.760703
# 1/2    33.589462
# 1/3    22.063666
# 1/4     6.586169
# dtype: float64

# %%
count3 = df.groupby(['sex']).size()
print(count3)
# Out:
# sex
# Female     49
# Male      836
# dtype: int64

# %%
#The sum of males and females does not add up due to the null entries

# %%
df.hist('year','sex',bins = 10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fc76e2ea640>,
# ...
#       dtype=object)

# %%
(df.birth_country == 'United States of America').sum()
# Out:
# 259

# %%
df['birth_year'] = pd.DatetimeIndex(df['birth_date']).year
df['death_year'] = pd.DatetimeIndex(df['death_date']).year
df.head()
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   laureate_type                     full_name  birth_date         birth_city  \
# ...

# %%
df['age'] = df['death_year'] - df['birth_year']
df
# Out:
#      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 906  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 907  2016       Peace                      The Nobel Peace Prize 2016
# 908  2016     Physics                 The Nobel Prize in Physics 2016
# 909  2016     Physics                 The Nobel Prize in Physics 2016
# 910  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# ...

# %%
column = df["age"]
column.max()
# Out:
# 103.0

# %%
column.min()
# Out:
# 39.0

# %%
column.mean()
# Out:
# 79.93591905564924

# %%
column.std()
# Out:
# 10.756484917351992

# %%
df.hist('age',bins = 100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc768e21fd0>]],
#       dtype=object)

# %%
df2 = df.copy()
df2.drop(['laureate_id'],axis=1,inplace=True)
df2
# Out:
#      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 906  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 907  2016       Peace                      The Nobel Peace Prize 2016
# 908  2016     Physics                 The Nobel Prize in Physics 2016
# 909  2016     Physics                 The Nobel Prize in Physics 2016
# 910  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# ...

# %%
#Age Column added above
